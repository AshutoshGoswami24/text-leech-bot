# %% [markdown]
# <a href="https://colab.research.google.com/github/AshutoshGoswami24/text-leech-bot/blob/v1.0.1/text-leech-bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil
from IPython.display import clear_output

#@title <h1><B><font color=red>𝗧𝗘𝗫𝗧-𝗟𝗘𝗘𝗖𝗛-𝗕𝗢𝗧</B>
# @markdown <div><center><a href="https://github.com/AshutoshGoswami24/text-leech-bot"><img height="200"  src="https://opengraph.githubassets.com/9s29ytrymhlrsfu1tqt1pzdxyfcsjeea/AshutoshGoswami24/text-leech-bot"></center></div>
# @markdown <br><center><h2><strong><font color=red>𝗧𝗘𝗫𝗧-𝗟𝗘𝗘𝗖𝗛-𝗕𝗢𝗧</strong></h2></center>


#@markdown <font color=ORANGE> Please enter the GitHub repository URL:
GITHUB_URL = "https://github.com/AshutoshGoswami24/text-leech-bot"  #@param {type:"string"}

# Determine base directory based on environment
base_dir = './repo'  # Save repo in ./repo directory relative to current directory

# Function to clone or update the repository
def clone_or_update_repo(repo_url, base_directory):
    repo_name = os.path.basename(repo_url).replace('.git', '')
    project_dir = os.path.join(base_directory, repo_name)

    # Check if the repository directory exists
    if os.path.exists(project_dir):
        print(f"Deleting existing repository at: {project_dir} ...")
        shutil.rmtree(project_dir)
        print("Deleted existing repository successfully!")

    # Clone the repository
    print(f"Cloning repository from {repo_url}...")
    clone_cmd = f"git clone {repo_url} {project_dir}"
    os.system(clone_cmd)
    print("Repository cloned successfully!")

    return project_dir

# Clone or update the repository
project_dir = clone_or_update_repo(GITHUB_URL, base_dir)

# Navigate to the project directory
print(f"Entering project directory: {os.path.basename(project_dir)}...")
os.chdir(project_dir)
print("Entered project directory successfully!")

clear_output()

#@markdown <font color=ORANGE>Please enter the requirements.txt file path:
PIP_INSTALL = "Installer"  #@param {type:"string"}

# Install required dependencies
print("Installing required dependencies...")
# !pip install -r {PIP_INSTALL}
print("All requirements installed successfully!")

clear_output()

#@markdown <font color=ORANGE> Install FFMPEG?
install_ffmpeg = "Yes"  #@param ["Yes", "No"]
if install_ffmpeg == "Yes":
    print("Installing FFMPEG...")
    os.system("apt-get install ffmpeg -qq")  # Install ffmpeg quietly
    print("FFMPEG installed successfully!")
else:
    print("Skipping FFMPEG installation.")

#@markdown ### <font color=ORANGE>Environment Variables

API_ID = ""  #@param {type:"string"}
os.environ['API_ID'] = API_ID

API_HASH = ""  #@param {type:"string"}
os.environ['API_HASH'] = API_HASH

BOT_TOKEN = ""  #@param {type:"string"}
os.environ['BOT_TOKEN'] = BOT_TOKEN

clear_output()

#@markdown <font color=ORANGE>Please enter the Profile command:
RUN_COMMAND = "python3 modules/main.py"  #@param {type:"string"}

# Run the bot
print(f"Running command: {RUN_COMMAND} ...")
# !{RUN_COMMAND}
print("Execution completed!")
# Out:
# Cloning repository from https://github.com/AshutoshGoswami24/text-leech-bot...
# Repository cloned successfully!
# Entering project directory: text-leech-bot...
# Entered project directory successfully!
# Installing required dependencies...
# Requirement already satisfied: async-lru in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 1)) (2.0.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 2)) (2023.5.7)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 3)) (3.1.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 4)) (3.4)
# Requirement already satisfied: mutagen in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 5)) (1.46.0)
# Requirement already satisfied: pyaes in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 6)) (1.6.1)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 7)) (3.18.0)
# Requirement already satisfied: pyrogram in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 8)) (2.0.83)
# Requirement already satisfied: pyromod in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 9)) (1.5)
# Requirement already satisfied: PySocks in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 10)) (1.7.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 11)) (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 12)) (2.31.0)
# Requirement already satisfied: soupsieve in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 13)) (2.4.1)
# Requirement already satisfied: TgCrypto in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 14)) (1.2.5)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 15)) (2.0.3)
# Requirement already satisfied: websockets in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 16)) (11.0.3)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 17)) (2023.6.22)
# Requirement already satisfied: motor in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 18)) (3.1.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 19)) (3.8.4)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 20)) (23.2.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 21)) (2023.3)
# Requirement already satisfied: umongo in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 22)) (3.1.0)
# Requirement already satisfied: speedtest-cli in /usr/local/lib/python3.10/dist-packages (from -r Installer (line 23)) (2.1.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from async-lru->-r Installer (line 1)) (4.12.2)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.10/dist-packages (from yt-dlp->-r Installer (line 17)) (3.20.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from yt-dlp->-r Installer (line 17)) (1.1.0)
# Requirement already satisfied: pymongo<5,>=4.1 in /usr/local/lib/python3.10/dist-packages (from motor->-r Installer (line 18)) (4.7.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->-r Installer (line 19)) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->-r Installer (line 19)) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->-r Installer (line 19)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->-r Installer (line 19)) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->-r Installer (line 19)) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->-r Installer (line 19)) (1.3.1)
# Requirement already satisfied: marshmallow>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from umongo->-r Installer (line 22)) (3.21.3)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow>=3.10.0->umongo->-r Installer (line 22)) (24.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo<5,>=4.1->motor->-r Installer (line 18)) (2.3.0)
# All requirements installed successfully!
# Installing FFMPEG...
# FFMPEG installed successfully!
# Running command: python3 modules/main.py ...
# online
# Unclosed tags: <b> (x1)
# yt-dlp -f "b[height<=720]/bv[height<=720]+ba/b/bv+ba" "https://videoscdn.classplusapp.com/efec3a101a6787b2f7f50b2a0c233ab830b7045ca8412fab394620eb91ea8f98/20230605150534-63048-1314355-cislw-ml/master.m3u8?key=1718454536-2-0-bf317de5d15eda5a6897fecafe916d0d&pass=38369212" -o "1330) Lecture - 11 (Latest Content for Essay Writing Episode - 3) .mp4" -R 25 --fragment-retries 25 --external-downloader aria2c --downloader-args "aria2c: -x 16 -j 32"
# [generic] Extracting URL: https://videoscdn.classplusapp.com/efec3a101a6787b2f7f50b2a0c233ab830b7045ca8412fab394620eb91ea8f...916d0d&pass=38369212
# [generic] master: Downloading webpage
# [generic] master: Downloading m3u8 information
# [generic] master: Checking m3u8 live status
# [info] master: Downloading 1 format(s): 2323
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 418
# [download] Destination: 1330) Lecture - 11 (Latest Content for Essay Writing Episode - 3) .mp4
# [download] 100% of  110.51MiB in 00:09:18 at 202.71KiB/s
# [FixupM3u8] Fixing MPEG-TS in MP4 container of "1330) Lecture - 11 (Latest Content for Essay Writing Episode - 3) .mp4"
# WARNING:pyrogram.session.session:Discarding packet: The msg_id belongs to over 300 seconds in the past. Most likely the client time has to be synchronized.
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '1330) Lecture - 11 (Latest Content for Essay Writing Episode - 3) .mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:13:56.06, start: 0.000000, bitrate: 1006 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720, 938 kb/s, 20 fps, 20 tbr, 90k tbn, 40 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5a34074baf80] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '1330) Lecture - 11 (Latest Content for Essay Writing Episode - 3) .mp4.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1280x720, q=2-31, 200 kb/s, 20 fps, 20 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.2 q=8.4 Lsize=N/A time=00:00:00.05 bitrate=N/A speed=0.00752x
# video:60kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# WARNING:pyrogram.parser.html:Unclosed tags: <b> (x1)
# yt-dlp -f "b[height<=720]/bv[height<=720]+ba/b/bv+ba" "https://videoscdn.classplusapp.com/efec3a101a6787b2f7f50b2a0c233ab830b7045ca8412fab394620eb91ea8f98/20230602130212-63048-1303681-dwcln-ml/master.m3u8?key=1718455120-16-0-50dcba3dc515299238734c191b51d4c7&pass=38369212" -o "1331) Lecture - 2 (Live).mp4" -R 25 --fragment-retries 25 --external-downloader aria2c --downloader-args "aria2c: -x 16 -j 32"
# [generic] Extracting URL: https://videoscdn.classplusapp.com/efec3a101a6787b2f7f50b2a0c233ab830b7045ca8412fab394620eb91ea8f...51d4c7&pass=38369212
# [generic] master: Downloading webpage
# [generic] master: Downloading m3u8 information
# [generic] master: Checking m3u8 live status
# [info] master: Downloading 1 format(s): 2323
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 1024
# [download] Destination: 1331) Lecture - 2 (Live).mp4
# [download] 100% of  220.40MiB in 00:35:06 at 107.16KiB/s
# [FixupM3u8] Fixing MPEG-TS in MP4 container of "1331) Lecture - 2 (Live).mp4"
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '1331) Lecture - 2 (Live).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:34:08.07, start: 0.000000, bitrate: 805 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720, 737 kb/s, 20 fps, 20 tbr, 90k tbn, 40 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x58df08f61380] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '1331) Lecture - 2 (Live).mp4.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1280x720, q=2-31, 200 kb/s, 20 fps, 20 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.1 q=7.2 Lsize=N/A time=00:00:00.05 bitrate=N/A speed=0.00593x
# video:53kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# WARNING:pyrogram.parser.html:Unclosed tags: <b> (x1)
# yt-dlp -f "b[height<=720]/bv[height<=720]+ba/b/bv+ba" "https://videoscdn.classplusapp.com/efec3a101a6787b2f7f50b2a0c233ab830b7045ca8412fab394620eb91ea8f98/20230602114732-63048-1303401-tgtmq-ml/master.m3u8?key=1718457262-12-0-a64f300394ea56b1e730bc5ac1e4beaf&pass=38369212" -o "1332) Lecture - 10 (Latest Content for Essay Writing Episode - 2) .mp4" -R 25 --fragment-retries 25 --external-downloader aria2c --downloader-args "aria2c: -x 16 -j 32"
# [generic] Extracting URL: https://videoscdn.classplusapp.com/efec3a101a6787b2f7f50b2a0c233ab830b7045ca8412fab394620eb91ea8f...e4beaf&pass=38369212
# [generic] master: Downloading webpage
# [generic] master: Downloading m3u8 information
# [generic] master: Checking m3u8 live status
# [info] master: Downloading 1 format(s): 2323
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 2090
# [download] Destination: 1332) Lecture - 10 (Latest Content for Essay Writing Episode - 2) .mp4
# [download]  17.4% of ~ 552.92MiB at  251.31KiB/s ETA 31:00 (frag 363/2090)
